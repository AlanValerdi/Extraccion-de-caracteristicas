# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling import freq_tbl

# %%
#Carga de datos
Micro_Retailer = pd.read_csv('madrid_spain_Cleansed.csv')

# %%
#Verificar información del dataframe
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26980 entries, 0 to 26979
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    26980 non-null  int64
#  1   id                            26980 non-null  int64
#  2   last_scraped                  26980 non-null  object
#  3   source                        26980 non-null  object
#  4   name                          26980 non-null  object
#  5   description                   26980 non-null  object
#  6   neighborhood_overview         26980 non-null  object
#  7   host_name                     26980 non-null  object
#  8   host_since                    26980 non-null  object
#  9   host_location                 26980 non-null  object
#  10  host_about                    26980 non-null  object
#  11  host_response_time            26980 non-null  object
# ...

# %%
# Analisis univariado de las variables categoricas
freq_tbl(Micro_Retailer)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   2024-09-11      26980         1.0              1.0
#
# ----------------------------------------------------------------
#
#             source  frequency  percentage  cumulative_perc
# 0      city scrape      21068    0.780875         0.780875
# 1  previous scrape       5912    0.219125         1.000000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0                            Habitación con baño privado         32
# 1                                             Habitación         24
# 2                                   Habitación en Madrid         23
# 3      H. Individual In Reformed Residence has wifi &...         20
# 4       Fantastic residence ``FUNWAY´´ north zone Madrid         19
# ...                                                  ...        ...
# ...

# %% [markdown]
# #Realizamos un grafico de frecuencia de nuestro dataframe con indice
# Filtro_index.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# plt.title('room_type')
# plt.xlabel('Tipo de habitación')
# plt.ylabel('Frecuencia')
# plt.show()
#
# Filtro_index2["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="instant_bookable") #True
#
# #filtro verde
# table12.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5)),
#
# #filtro azul
# Filtro_index4.plot(kind='area', alpha=0.5, figsize=(10,4))
#
# #realizamos un grafico para visualizar la frecuencia de la variable
# table16.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un analisis univariado de una variable categorica en especifico
table1=freq_tbl(Micro_Retailer['room_type'])
# table1

#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2=table1.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relecantes de la variable
Filtro = table2[table2['frequency']>1]
Filtro

#Ajusto el indice del Dataframe
Filtro_index = Filtro.set_index('room_type')
Filtro_index


#Realizamos un grafico de frecuencia de nuestro dataframe con indice
Filtro_index.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
plt.title('room_type')
plt.xlabel('Tipo de habitación')
plt.ylabel('Frecuencia')
plt.show()

# %%
#Obtengo un analisis univariado de una variable categorica en especifico
table11=freq_tbl(Micro_Retailer['instant_bookable'])
# table1

#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table21=table11.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relecantes de la variable
Filtro2 = table21[table21['frequency']>1]
Filtro2

#Ajusto el indice del Dataframe
Filtro_index2 = Filtro2.set_index('instant_bookable')
Filtro_index2


#Realizamos un grafico de frecuencia de nuestro dataframe con indice
Filtro_index2["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="instant_bookable") #True
# Out:
# <Axes: title={'center': 'instant_bookable'}, ylabel='frequency'>

# %%
table12=freq_tbl(Micro_Retailer['license'])
# table1

#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table22=table12.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relecantes de la variable
Filtro3 = table22[table22['frequency']>1]

#Ajusto el indice del Dataframe
Filtro_index3 = Filtro3.set_index('license')
Filtro_index3

table12.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5)),
# Out:
# (<Axes: xlabel='frequency', ylabel='cumulative_perc'>,)

# %%
table14=freq_tbl(Micro_Retailer['first_review'])
# table1

table24=table14.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro4 = table24[table24['frequency']>1]
Filtro4

#Ajusto el indice del Dataframe
Filtro_index4 = Filtro4.set_index('first_review')
Filtro_index4

# #Realizamos un grafico de frecuencia de nuestro dataframe con indice
Filtro_index4.plot(kind='area', alpha=0.5, figsize=(10,4))
# Out:
# <Axes: xlabel='first_review'>

# %%
table15=freq_tbl(Micro_Retailer['property_type'])
# table1

table25=table15.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro5 = table25[table25['frequency']>100]
Filtro5

#Ajusto el indice del Dataframe
Filtro_index5 = Filtro5.set_index('property_type')
Filtro_index5

#Realizamos un grafico de frecuencia de nuestro dataframe con indice
Filtro_index5.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
plt.title('room_type')
plt.xlabel('Tipo de habitación')
plt.ylabel('Frecuencia')
plt.show()

# %%
table16=freq_tbl(Micro_Retailer['bathrooms_text'])
# table1

table26=table16.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro6 = table26[table26['frequency']>100]
Filtro6

#Ajusto el indice del Dataframe
Filtro_index6 = Filtro6.set_index('bathrooms_text')
Filtro_index6

#realizamos un grafico para visualizar la frecuencia de la variable
table16.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
table17=freq_tbl(Micro_Retailer['neighbourhood_group_cleansed'])
table17

# table2
table27=table17.drop(['percentage', 'cumulative_perc'], axis=1)

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro7 = table27[table27['frequency']>100]
Filtro7

#Ajusto el indice del Dataframe
Filtro_index7 = Filtro7.set_index('neighbourhood_group_cleansed')
Filtro_index7

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index7.plot(kind='area', alpha=0.5, figsize=(10,4))
# Out:
# <Axes: xlabel='neighbourhood_group_cleansed'>

# %%
table18=freq_tbl(Micro_Retailer['host_location'])
# table1

table28=table18.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro8 = table28[table28['frequency']>1]

#Ajusto el indice del Dataframe
Filtro_index8 = Filtro8.set_index('host_location')
Filtro_index8

#realizamos un grafico para visualizar la frecuencia de la variable
table18.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
table19=freq_tbl(Micro_Retailer['amenities'])
# table1

table29=table19.drop(['percentage', 'cumulative_perc'], axis=1)
table29

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro9 = table29[table29['frequency']>10]
Filtro9

#Ajusto el indice del Dataframe
Filtro_index9 = Filtro9.set_index('amenities')
Filtro_index9

#Realizamos un grafico de frecuencia de nuestro dataframe con indice
Filtro_index9.plot(kind='area', alpha=0.5, figsize=(10,4))
plt.xticks(ticks=range(len(Filtro_index9.index)), labels=[f'amenidad {i+1}' for i in range(len(Filtro_index9.index))], rotation=90)
plt.show()

# %%
table110=freq_tbl(Micro_Retailer['source'])
# table1

table210=table110.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro10 = table210[table210['frequency']>1]
Filtro10

#Ajusto el indice del Dataframe
Filtro_index10 = Filtro10.set_index('source')
Filtro_index10

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index10["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="source") #True
# Out:
# <Axes: title={'center': 'source'}, ylabel='frequency'>

# %%
table111=freq_tbl(Micro_Retailer['neighborhood_overview'])
# table1

table211=table111.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#realizamos un grafico para visualizar la frecuencia de la variable
table111.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5)),
# Out:
# (<Axes: xlabel='frequency', ylabel='cumulative_perc'>,)

# %%
tablw112=freq_tbl(Micro_Retailer['host_name'])
# table1

table212=tablw112.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro12 = table212[table212['frequency']>100]
Filtro12

#Ajusto el indice del Dataframe
Filtro_index12 = Filtro12.set_index('host_name')
Filtro_index12

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index12.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
plt.title('room_type')
plt.xlabel('Tipo de habitación')
plt.ylabel('Frecuencia')
plt.show()

# %%
table113=freq_tbl(Micro_Retailer['host_since'])
# table1

table213=table113.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro13 = table213[table213['frequency']>100]
Filtro13

#Ajusto el indice del Dataframe
Filtro_index13 = Filtro13.set_index('host_since')
Filtro_index13

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index13["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="host_since") #True
# Out:
# <Axes: title={'center': 'host_since'}, ylabel='frequency'>

# %%
table114=freq_tbl(Micro_Retailer['host_about'])
# table1

table214=table114.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro14 = table214[table214['frequency']>50]
Filtro14

#Ajusto el indice del Dataframe
Filtro_index14 = Filtro14.set_index('host_about')
Filtro_index14

#realizamos un grafico para visualizar la frecuencia de la variable
# Exclude the first description
Filtro_index14_filtered = Filtro_index14.iloc[1:]
Filtro_index14_filtered.plot(kind='area', alpha=0.5, figsize=(10,4), title="host_about_solo_incluye_descripcion")
plt.xticks(ticks=range(len(Filtro_index14_filtered.index)), labels=[f'descripcion {i+1}' for i in range(len(Filtro_index14_filtered.index))], rotation=90)
plt.show()

Filtro_index14.plot(kind='area', alpha=0.5, figsize=(10,4), title="host_about_incluye_descripcion_no_proporcionada")
plt.xticks(ticks=range(len(Filtro_index14.index)), labels=[f'descripcion {i+1}' for i in range(len(Filtro_index14.index))], rotation=90)
plt.show()

# %%
table115=freq_tbl(Micro_Retailer['host_response_time'])
# table1

table215=table115.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro15 = table215[table215['frequency']>100]
Filtro15

#Ajusto el indice del Dataframe
Filtro_index15 = Filtro15.set_index('host_response_time')
Filtro_index15

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index15["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="host_response_time") #True
# Out:
# <Axes: title={'center': 'host_response_time'}, ylabel='frequency'>

# %%
table116=freq_tbl(Micro_Retailer['host_response_rate'])
# table1

table216=table116.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro16 = table216[table216['frequency']>100]
Filtro16

#Ajusto el indice del Dataframe
Filtro_index16 = Filtro16.set_index('host_response_rate')
Filtro_index16

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index16.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
plt.title('host_rensponse_rate')
plt.xlabel('porcentaje ')
plt.ylabel('Frecuencia')
plt.show()

# %%
table117=freq_tbl(Micro_Retailer['host_acceptance_rate'])
# table1

table217=table117.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro17 = table217[table217['frequency']>100]
Filtro17

#Ajusto el indice del Dataframe
Filtro_index17 = Filtro17.set_index('host_acceptance_rate')
Filtro_index

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index17.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
plt.title('host_acceptance_rate')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
plt.show()

# %%
table118=freq_tbl(Micro_Retailer['host_is_superhost'])
# table1

table218=table118.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro18 = table218[table218['frequency']>100]
Filtro18

#Ajusto el indice del Dataframe
Filtro_index18 = Filtro18.set_index('host_is_superhost')
Filtro_index18

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index18["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="host_is_superhost") #True
# Out:
# <Axes: title={'center': 'host_is_superhost'}, ylabel='frequency'>

# %%
table119=freq_tbl(Micro_Retailer['host_verifications'])
# table1

table219=table119.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro19 = table219[table219['frequency']>1]
Filtro19

#Ajusto el indice del Dataframe
Filtro_index19 = Filtro19.set_index('host_verifications')
Filtro_index19

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index19.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <Axes: xlabel='host_verifications'>

# %%
table120=freq_tbl(Micro_Retailer['host_identity_verified'])
# table1

table220=table120.drop(['percentage', 'cumulative_perc'], axis=1)
# table2

#Obtengo un filtro de los valores mas relevantes de la variable
Filtro20 = table220[table220['frequency']>100]
Filtro20

#Ajusto el indice del Dataframe
Filtro_index20 = Filtro20.set_index('host_identity_verified')
Filtro_index20

#realizamos un grafico para visualizar la frecuencia de la variable
Filtro_index20["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%", startangle=90, shadow=False, title="host_identity_verified") #True
# Out:
# <Axes: title={'center': 'host_identity_verified'}, ylabel='frequency'>

# %%
#Corraboramos valore nulos
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                      0
# id                              0
# last_scraped                    0
# source                          0
# name                            0
# description                     0
# neighborhood_overview           0
# host_name                       0
# host_since                      0
# host_location                   0
# host_about                      0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_verifications              0
# host_identity_verified          0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms_text                  0
# amenities                       0
# price                           0
# ...

# %%
Micro_Retailer["host_response_rate"].info()
n=26980
# Convertimos la columna 'host_acceptance_rate' a valores numéricos
Micro_Retailer['host_response_rate'] = Micro_Retailer['host_response_rate'].str.replace('%', '').astype(float)

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['host_response_rate'].max()
Min = Micro_Retailer['host_response_rate'].min()
Limites = [Min, Max]
print("limites: --------\n", Limites)

#Calculamos el rango R
R = Max - Min
print("rango r: --------\n", R)

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("ancho de cada intervalo i: --------\n", i)

#Categorizacion de variables
intervalos=np.linspace(0.0, 1.0, 16)
intervalos

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['host_response_rate'] = pd.cut(x=Micro_Retailer['host_response_rate'], bins=intervalos, labels=categorias, include_lowest=True)
Micro_Retailer['host_response_rate']

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts2 = Micro_Retailer['host_response_rate'].value_counts().sort_index()
categoria_counts2.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  object
# dtypes: object(1)
# memory usage: 210.9+ KB
# limites: --------
#  [0.0, 100.0]
# rango r: --------
#  100.0
# ancho de cada intervalo i: --------
#  8.333333333333334
# <Axes: xlabel='host_response_rate'>

# %%
Micro_Retailer["host_acceptance_rate"].info()
n=26980
# Convertimos la columna 'host_acceptance_rate' a valores numéricos
# Micro_Retailer['host_acceptance_rate'] = Micro_Retailer['host_acceptance_rate'].str.rstrip('%').astype('float') / 100.0

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['host_acceptance_rate'].max()
Min = Micro_Retailer['host_acceptance_rate'].min()
Limites = [Min, Max]
print("limites: --------\n", Limites)

#Calculamos el rango R
R = Max - Min
print("rango r: --------\n", R)

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("ancho de cada intervalo i: --------\n", i)

#Categorizacion de variables
intervalos=np.linspace(0.0, 1.0, 16)
intervalos

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['host_acceptance_rate_categoria'] = pd.cut(x=Micro_Retailer['host_acceptance_rate'], bins=intervalos, labels=categorias, include_lowest=True)
Micro_Retailer['host_acceptance_rate_categoria']

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts2 = Micro_Retailer['host_acceptance_rate_categoria'].value_counts().sort_index()
categoria_counts2.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# limites: --------
#  [0.0, 1.0]
# rango r: --------
#  1.0
# ancho de cada intervalo i: --------
#  0.08333333333333333
# <Axes: xlabel='host_acceptance_rate_categoria'>

# %%
Micro_Retailer["host_total_listings_count"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['host_total_listings_count'].max()
Min = Micro_Retailer['host_total_listings_count'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, num_intervalos)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['host_total_listings_count_categoria'] = pd.cut(x=Micro_Retailer['host_total_listings_count'], bins=intervalos, labels=categorias, include_lowest=True)
Micro_Retailer['host_total_listings_count_categoria']

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts2 = Micro_Retailer['host_total_listings_count_categoria'].value_counts().sort_index()
categoria_counts2.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 67.0]
#
# -------- rango r: --------
#  66.0
#
# -------- ancho de cada intervalo i: --------
#  5.5
#
# -------- intervalos: --------
#  [ 1.  7. 13. 19. 25. 31. 37. 43. 49. 55. 61. 67.]
# -------- num de intervalos: --------
#  12
# <Axes: xlabel='host_total_listings_count_categoria'>

# %%
Micro_Retailer["accommodates"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['accommodates'].max()
Min = Micro_Retailer['accommodates'].min()
Limites = [Min, Max]

print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)
print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, num_intervalos)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['accommodates_categoria'] = pd.cut(x=Micro_Retailer['accommodates'], bins=intervalos, labels=categorias, include_lowest=True)
Micro_Retailer['accommodates_categoria']

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts1 = Micro_Retailer['accommodates_categoria'].value_counts().sort_index()
categoria_counts1.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  int64
# dtypes: int64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1, 16]
#
# -------- rango r: --------
#  15
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  1.25
#
# -------- intervalos: --------
#  [ 1.          2.36363636  3.72727273  5.09090909  6.45454545  7.81818182
#   9.18181818 10.54545455 11.90909091 13.27272727 14.63636364 16.        ]
# -------- num de intervalos: --------
#  12
# <Axes: xlabel='accommodates_categoria'>

# %%
Micro_Retailer["beds"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['beds'].max()
Min = Micro_Retailer['beds'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['beds_categoria'] = pd.cut(x=Micro_Retailer['beds'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['beds_categoria'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [0.0, 3.0]
#
# -------- rango r: --------
#  3.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.25
#
# -------- intervalos: --------
#  [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75 2.   2.25 2.5  2.75 3.  ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='beds_categoria'>

# %%
Micro_Retailer["price"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['price'].max()
Min = Micro_Retailer['price'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['price_categoria'] = pd.cut(x=Micro_Retailer['price'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['price_categoria'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 21000.0]
#
# -------- rango r: --------
#  20999.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  1749.9166666666667
#
# -------- intervalos: --------
#  [1.00000000e+00 1.75091667e+03 3.50083333e+03 5.25075000e+03
#  7.00066667e+03 8.75058333e+03 1.05005000e+04 1.22504167e+04
#  1.40003333e+04 1.57502500e+04 1.75001667e+04 1.92500833e+04
#  2.10000000e+04]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='price_categoria'>

# %%
Micro_Retailer["maximum_nights_avg_ntm"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['maximum_nights_avg_ntm'].max()
Min = Micro_Retailer['maximum_nights_avg_ntm'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['maximum_nights_avg_ntm'] = pd.cut(x=Micro_Retailer['maximum_nights_avg_ntm'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['maximum_nights_avg_ntm'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 1825.0]
#
# -------- rango r: --------
#  1824.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  152.0
#
# -------- intervalos: --------
#  [1.000e+00 1.530e+02 3.050e+02 4.570e+02 6.090e+02 7.610e+02 9.130e+02
#  1.065e+03 1.217e+03 1.369e+03 1.521e+03 1.673e+03 1.825e+03]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='maximum_nights_avg_ntm'>

# %%
Micro_Retailer["availability_365"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['availability_365'].max()
Min = Micro_Retailer['availability_365'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['availability_365'] = pd.cut(x=Micro_Retailer['availability_365'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['availability_365'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  int64
# dtypes: int64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [0, 365]
#
# -------- rango r: --------
#  365
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  30.416666666666668
#
# -------- intervalos: --------
#  [  0.          30.41666667  60.83333333  91.25       121.66666667
#  152.08333333 182.5        212.91666667 243.33333333 273.75
#  304.16666667 334.58333333 365.        ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='availability_365'>

# %%
Micro_Retailer["number_of_reviews"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['number_of_reviews'].max()
Min = Micro_Retailer['number_of_reviews'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['number_of_reviews'] = pd.cut(x=Micro_Retailer['number_of_reviews'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['number_of_reviews'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [0.0, 121.0]
#
# -------- rango r: --------
#  121.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  10.083333333333334
#
# -------- intervalos: --------
#  [  0.          10.08333333  20.16666667  30.25        40.33333333
#   50.41666667  60.5         70.58333333  80.66666667  90.75
#  100.83333333 110.91666667 121.        ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='number_of_reviews'>

# %%
Micro_Retailer["review_scores_location"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_location'].max()
Min = Micro_Retailer['review_scores_location'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_location'] = pd.cut(x=Micro_Retailer['review_scores_location'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_location'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 5.0]
#
# -------- rango r: --------
#  4.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.3333333333333333
#
# -------- intervalos: --------
#  [1.         1.33333333 1.66666667 2.         2.33333333 2.66666667
#  3.         3.33333333 3.66666667 4.         4.33333333 4.66666667
#  5.        ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_location'>

# %%
Micro_Retailer["review_scores_value"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_value'].max()
Min = Micro_Retailer['review_scores_value'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_value'] = pd.cut(x=Micro_Retailer['review_scores_value'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_value'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [4.1, 5.0]
#
# -------- rango r: --------
#  0.9000000000000004
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.07500000000000002
#
# -------- intervalos: --------
#  [4.1   4.175 4.25  4.325 4.4   4.475 4.55  4.625 4.7   4.775 4.85  4.925
#  5.   ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_value'>

# %%
Micro_Retailer["reviews_per_month"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['reviews_per_month'].max()
Min = Micro_Retailer['reviews_per_month'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['reviews_per_month'] = pd.cut(x=Micro_Retailer['reviews_per_month'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['reviews_per_month'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [0.01, 4.46]
#
# -------- rango r: --------
#  4.45
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.37083333333333335
#
# -------- intervalos: --------
#  [0.01       0.38083333 0.75166667 1.1225     1.49333333 1.86416667
#  2.235      2.60583333 2.97666667 3.3475     3.71833333 4.08916667
#  4.46      ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='reviews_per_month'>

# %%
Micro_Retailer["review_scores_communication"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_communication'].max()
Min = Micro_Retailer['review_scores_communication'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_communication'] = pd.cut(x=Micro_Retailer['review_scores_communication'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_communication'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 5.0]
#
# -------- rango r: --------
#  4.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.3333333333333333
#
# -------- intervalos: --------
#  [1.         1.33333333 1.66666667 2.         2.33333333 2.66666667
#  3.         3.33333333 3.66666667 4.         4.33333333 4.66666667
#  5.        ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_communication'>

# %%
Micro_Retailer["review_scores_checkin"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_checkin'].max()
Min = Micro_Retailer['review_scores_checkin'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_checkin'] = pd.cut(x=Micro_Retailer['review_scores_checkin'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_checkin'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [4.1, 5.0]
#
# -------- rango r: --------
#  0.9000000000000004
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.07500000000000002
#
# -------- intervalos: --------
#  [4.1   4.175 4.25  4.325 4.4   4.475 4.55  4.625 4.7   4.775 4.85  4.925
#  5.   ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_checkin'>

# %%
Micro_Retailer["review_scores_cleanliness"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_cleanliness'].max()
Min = Micro_Retailer['review_scores_cleanliness'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_cleanliness'] = pd.cut(x=Micro_Retailer['review_scores_cleanliness'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_cleanliness'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [1.0, 5.0]
#
# -------- rango r: --------
#  4.0
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.3333333333333333
#
# -------- intervalos: --------
#  [1.         1.33333333 1.66666667 2.         2.33333333 2.66666667
#  3.         3.33333333 3.66666667 4.         4.33333333 4.66666667
#  5.        ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_cleanliness'>

# %%
Micro_Retailer["review_scores_accuracy"].info()
n=26980

#Obtenemos el limite superior y el limite inferior de la columna objetivo
Max = Micro_Retailer['review_scores_accuracy'].max()
Min = Micro_Retailer['review_scores_accuracy'].min()
Limites = [Min, Max]
print("-------- limites: --------\n", Limites, "\n")

#Calculamos el rango R
R = Max - Min
print("-------- rango r: --------\n", R, "\n")

#Calculamos el numero de intervalos de Clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
if(ni>12):
  ni=12
num_intervalos = round(ni)

print("-------- ni: --------\n", ni, "\n")

#Calculamos el ancho de cada intervalo "i"
i = R/ni
print("-------- ancho de cada intervalo i: --------\n", i , "\n")

#Categorizacion de variables
intervalos=np.linspace(Min, Max, ni+1)
print("-------- intervalos: --------\n", intervalos)
print("-------- num de intervalos: --------\n", intervalos.__len__(), "\n")

#Creamos las categorias
categorias = [f"{intervalos[i]:.4f}-{intervalos[i+1]:.4f}" for i in range(len(intervalos) - 1)]

Micro_Retailer['review_scores_accuracy'] = pd.cut(x=Micro_Retailer['review_scores_accuracy'], bins=intervalos, labels=categorias, include_lowest=True)

# Convertimos las categorías a valores numéricos para poder graficar
categoria_counts = Micro_Retailer['review_scores_accuracy'].value_counts().sort_index()
categoria_counts.plot(kind='bar', width=0.8, figsize=(10,5), color='gray')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26980 entries, 0 to 26979
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 26980 non-null  float64
# dtypes: float64(1)
# memory usage: 210.9 KB
# -------- limites: --------
#  [4.1, 5.0]
#
# -------- rango r: --------
#  0.9000000000000004
#
# -------- ni: --------
#  12
#
# -------- ancho de cada intervalo i: --------
#  0.07500000000000002
#
# -------- intervalos: --------
#  [4.1   4.175 4.25  4.325 4.4   4.475 4.55  4.625 4.7   4.775 4.85  4.925
#  5.   ]
# -------- num de intervalos: --------
#  13
# <Axes: xlabel='review_scores_accuracy'>
